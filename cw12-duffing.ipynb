# %%
import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import sombrero as smb

# %%
smb.sombrero(-.9,0,np.arange(0, 2*np.pi*50, 0.001), .18)
# Out:
# array([-0.9       , -0.9       , -0.89999999, ..., -0.81632627,
#        -0.81628781, -0.81624945])

# %%
smb.sombrero(.9,0,np.arange(0, 2*np.pi*50, 0.001), .18)
# Out:
# array([0.9       , 0.9       , 0.90000035, ..., 1.17531489, 1.17538383,
#        1.17545248])

# %%
smb.sombrero(.2,0.1,np.arange(0, 2*np.pi*50, 0.001), .25)
# Out:
# array([0.2       , 0.20010005, 0.20020052, ..., 1.25763504, 1.25779269,
#        1.25794981])

# %%
smb.sombrero(.201,0.1,np.arange(0, 2*np.pi*50, 0.001), .25)
# Out:
# array([ 0.201     ,  0.20110005,  0.20120052, ..., -0.70032192,
#        -0.70026112, -0.70020043])

# %%
smb.sombrero(0,0,np.arange(0, 2*np.pi*50, 0.001), .4)
# Out:
# array([0.00000000e+00, 0.00000000e+00, 4.00355745e-07, ...,
#        9.84830804e-01, 9.85302481e-01, 9.85774469e-01])

# %%
smb.sombrero(0,0,np.arange(0, 2*np.pi*1000, 0.001), .4)
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  4.00355745e-07, ...,
#        -3.19847089e-01, -3.19145498e-01, -3.18443969e-01])

# %%
smb.sombrero(-.9,0,np.arange(0, 2*np.pi*50, 0.001), .18)[-1]
# Out:
# -0.8162494463974044
